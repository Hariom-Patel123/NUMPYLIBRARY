# %% [markdown]
# <a href="https://colab.research.google.com/github/Hariom-Patel123/NUMPYLIBRARY/blob/main/nump1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([4,8,12,16,20])
print(a)
# Out:
# [ 4  8 12 16 20]

# %%
b=np.array([4,8,12,16,20])
print(a+b)
# Out:
# [ 8 16 24 32 40]

# %%
b+2
# Out:
# array([ 6, 10, 14, 18, 22])

# %%
b**2
# Out:
# array([ 16,  64, 144, 256, 400])

# %%
##GIVEN A LIST OF THE PRIXCES
prices=
